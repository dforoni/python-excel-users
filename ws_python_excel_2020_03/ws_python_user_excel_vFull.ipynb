# %% [markdown]
# # <font color='Magenta'> Workshop - Python para usuárias de Excel </font>

# %% [markdown]
# ## <font color='Magenta'> Bibliotecas </font>
#
# Nesta etapa vamos importar as bibliotecas que iremos utilizar neste workshop.

# %%
import pandas as pd
import time

# %% [markdown]
# ## <font color='Magenta'> Carregando os dados </font>
#
# Nesta etapa buscamos na nossa máquina o arquivo excel.

# %%
# %%time
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6b2caec1-2cf3-400b-b65d-c239c3b64ee9" name="files[]" multiple disabled />
#      <output id="result-6b2caec1-2cf3-400b-b65d-c239c3b64ee9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-09066a3175b7> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'from google.colab import files\nuploaded = files.upload()')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
#      66   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: google.colab._files is undefined

# %% [markdown]
# ## <font color='Magenta'> Carregando os dados com a biblioteca Pandas </font>
#
# A primeira etapa é importar o arquivo para o Python, assim conseguiremos trabalhar os dados.
#
# O método que iremos usar para a importação será o *read_excel* da biblioteca Pandas, este método suporta as extensões xls e xlsx.
#
# Existem outros métodos para importar arquivos de outras extensões (csv, txt e etc).

# %%
# Estamos carregando o arquivo Excel e colocando dentro de um objeto, neste caso dentro do objeto "dados".
dados = pd.read_excel('salarios.xlsx')
print(dados)
# Out:
#              Id                            job  ... discount_salary  total_salary
# 0            17  AGENTE DE ORGANIZACAO ESCOLAR  ...             0.0     2106490.0
# 1            30    PROFESSOR EDUCACAO BASICA I  ...             0.0     4106750.0
# 2            49   PROFESSOR EDUCACAO BASICA II  ...             0.0     1316320.0
# 3            63   PROFESSOR EDUCACAO BASICA II  ...             0.0     2897890.0
# 4            65         OFICIAL ADMINISTRATIVO  ...             0.0     2386210.0
# ...         ...                            ...  ...             ...           ...
# 299801  1048532    PROFESSOR EDUCACAO BASICA I  ...             0.0     4458820.0
# 299802  1048538  AGENTE DE ORGANIZACAO ESCOLAR  ...             0.0     1585700.0
# 299803  1048541   PROFESSOR EDUCACAO BASICA II  ...             0.0     3227480.0
# 299804  1048551                      MEDICO II  ...             0.0     5473300.0
# 299805  1048573   PROFESSOR EDUCACAO BASICA II  ...             0.0     3448160.0
#
# [299806 rows x 10 columns]

# %% [markdown]
# ## <font color='Magenta'> Importando outras sheets no Python </font>
#
# Por padrão o Pandas importa a primeira sheet do arquivo,       mas na vida real sabemos que não é assim que funciona e que precisamos também de outras *sheets*, abaixo vamos importar uma sheet específica.
#
# Para isso usaremos o argumento chamado *sheet_name*, com ele conseguimos dizer qual a sheet que queremos importar.

# %%
new_sheet = pd.read_excel('salarios.xlsx', sheet_name='salario_mensal_02')
print(new_sheet)
# Out:
#           Id                        job  ... total_salary  Unnamed: 10
# 0        1.0     OFICIAL ADMINISTRATIVO  ...    1929340.0          NaN
# 1        2.0                   SD 2C PM  ...    2265960.0          NaN
# 2        3.0                   1TEN  PM  ...    6933040.0          NaN
# 3        4.0                   MAJ   PM  ...   10568360.0          NaN
# 4        5.0  AG.TEC. DE ASSIT. A SAUDE  ...    3561880.0          NaN
# ...      ...                        ...  ...          ...          ...
# 1039040  NaN                        NaN  ...          NaN          NaN
# 1039041  NaN                        NaN  ...          NaN          NaN
# 1039042  NaN                        NaN  ...          NaN          NaN
# 1039043  NaN                        NaN  ...          NaN          NaN
# 1039044  NaN                        NaN  ...          NaN    4629740.0
#
# [1039045 rows x 11 columns]

# %% [markdown]
# ## <font color='Magenta'> Usando uma coluna como índice  </font>
#
# As vezes necessitamos usar uma coluna como índice, e para isto usaremos o argumento do *read_excel* chamado *index_col*.

# %%
indice = pd.read_excel('salarios.xlsx', sheet_name='salario_mensal_01', index_col=0)
print(indice)

# %% [markdown]
# ## <font color='Magenta'> Pulando linhas e colunas </font>
#
# Por padrão o método read_excel assume que a primeira linha do dataframe é uma lista de colunas formando assim o cabeçario do dataframe (os nomes das colunas).
#
# Para isto necessitamos dos argumentos header e skiprows para manipulação  do cabeçario e das linhas.

# %%
skip = pd.read_excel('salarios.xlsx', sheet_name='salario_mensal_01', header=None, skiprows=1, index_col=0)
print(skip)
# Out:
#                                      1         2  ...    8          9
# 0                                                 ...
# 17       AGENTE DE ORGANIZACAO ESCOLAR  EDUCACAO  ...  0.0  2106490.0
# 30         PROFESSOR EDUCACAO BASICA I  EDUCACAO  ...  0.0  4106750.0
# 49        PROFESSOR EDUCACAO BASICA II  EDUCACAO  ...  0.0  1316320.0
# 63        PROFESSOR EDUCACAO BASICA II  EDUCACAO  ...  0.0  2897890.0
# 65              OFICIAL ADMINISTRATIVO     SAUDE  ...  0.0  2386210.0
# ...                                ...       ...  ...  ...        ...
# 1048532    PROFESSOR EDUCACAO BASICA I  EDUCACAO  ...  0.0  4458820.0
# 1048538  AGENTE DE ORGANIZACAO ESCOLAR  EDUCACAO  ...  0.0  1585700.0
# 1048541   PROFESSOR EDUCACAO BASICA II  EDUCACAO  ...  0.0  3227480.0
# 1048551                      MEDICO II     SAUDE  ...  0.0  5473300.0
# 1048573   PROFESSOR EDUCACAO BASICA II  EDUCACAO  ...  0.0  3448160.0
#
# [299806 rows x 9 columns]

# %% [markdown]
# ## <font color='Magenta'> Importando colunas específicas </font>
#
# Muitas vezes não necessitamos de todas as colunas do dataframe,
# e para isto existe um argumento que nos ajuda selecionar apenas as colunas que necessitamos, que é o usecols.

# %%
col = pd.read_excel('salarios.xlsx', sheet_name='salario_mensal_01', header=None, skiprows=1, usecols='A,D')
print(col)
# Out:
#               0        3
# 0            17  1549390
# 1            30  3517150
# 2            49  2959130
# 3            63  3902780
# 4            65  2434830
# ...         ...      ...
# 299801  1048532  5190870
# 299802  1048538  1662140
# 299803  1048541  6188690
# 299804  1048551  6575080
# 299805  1048573  4336260
#
# [299806 rows x 2 columns]

# %% [markdown]
# ## <font color='Magenta'> Resposta - Desafio 1 </font>
#
# Importar o arquivo csv chamado: monthly_salary_brazil

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b05b1e57-1b71-4f02-84c3-d4fa7237a996" name="files[]" multiple disabled />
#      <output id="result-b05b1e57-1b71-4f02-84c3-d4fa7237a996">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving monthly_salary_brazil.csv to monthly_salary_brazil.csv

# %%
# Estamos carregando o arquivo CSV e colocando dentro de um objeto, neste caso dentro do objeto "dados".
dados = pd.read_csv('monthly_salary_brazil.csv', error_bad_lines=False)
print(dados)
# Out:
#         Id                           job  ... discount_salary  total_salary
# 0        1        OFICIAL ADMINISTRATIVO  ...             0.0       1929.34
# 1        2                      SD 2C PM  ...             0.0       2265.96
# 2        3                      1TEN  PM  ...             0.0       6933.04
# 3        4                      MAJ   PM  ...             0.0      10568.36
# 4        5     AG.TEC. DE ASSIT. A SAUDE  ...             0.0       3561.88
# ...    ...                           ...  ...             ...           ...
# 9984  9995         AUXILIAR SERV. GERAIS  ...             0.0       1885.66
# 9985  9996  PROFESSOR EDUCACAO BASICA II  ...             0.0       2379.93
# 9986  9997  PROFESSOR EDUCACAO BASICA II  ...             0.0       1144.39
# 9987  9998        OFICIAL ADMINISTRATIVO  ...             0.0       1404.60
# 9988  9999    INVESTIGADOR POL.1A CLASSE  ...             0.0       6387.99
#
# [9989 rows x 10 columns]
# b'Skipping line 846: expected 10 fields, saw 11\nSkipping line 848: expected 10 fields, saw 11\nSkipping line 1689: expected 10 fields, saw 11\nSkipping line 2312: expected 10 fields, saw 11\nSkipping line 3669: expected 10 fields, saw 11\nSkipping line 7125: expected 10 fields, saw 11\nSkipping line 7189: expected 10 fields, saw 11\nSkipping line 8553: expected 10 fields, saw 11\nSkipping line 8835: expected 10 fields, saw 11\nSkipping line 9282: expected 10 fields, saw 11\n'

# %% [markdown]
# ## <font color='Magenta'> Importando múltiplas abas do arquivo em xlsx </font>
#
# Primeiro vamos aprender uma outra maneira de importar arquivos no Colab.

# %%
# Biblioteca que faz chamada para o Google Drive
from google.colab import drive

# Isso solicitará autorização com a sua conta do Google Drive
drive.mount('/content/drive')

# Lista o conteúdo do seu Google Drive
# !ls "/content/drive/My Drive"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
#  1.Projetos	        insurance.csv
#  2.Worksops	       'Orçamento mensal.gsheet'
#  3.Cursos	       'Passo a passo de uma modelagem (FIFA)-Versão3.ipynb'
#  Atuação_20191021.rar   Teste_DS_Deborah_Foroni.ipynb
# 'Colab Notebooks'

# %% [markdown]
# Agora vamos usar a função *ExcelFile* para a leitura do arquivo Excel.

# %%
xlsx = pd.ExcelFile('/content/drive/My Drive/2.Worksops/Python_Uusarias_Excel/insurance.xlsx')

# %% [markdown]
# O atributo *sheet_names* retorna os nomes das abas do arquivo Excel.

# %%
xlsx.sheet_names
# Out:
# ['insurance', 'insurance2']

# %% [markdown]
# O método *parse* retorna os dados da aba que desejamos.

# %%
df1 = xlsx.parse('insurance')
df1.head(3)
# Out:
#    id  age     sex    bmi  children smoker     region    charges
# 0   1   19  female  27.90         0    yes  southwest  168849.24
# 1   2   18    male  33.77         1     no  southeast  172555.23
# 2   3   28    male  33.00         3     no  southeast   44494.62

# %%
df2 = xlsx.parse('insurance2')
df2.head(3)
# Out:
#    id  ID country
# 0   1   1  Brazil
# 1   2   2  Brazil
# 2   3   3  Brazil

# %% [markdown]
# ## <font color='Magenta'> Visualizando os dados do arquivo </font>
#
# Os métodos *head* , *tail*, *info*, *unique* e os atributos *shape* e *columns* fazem parte da biblioteca Pandas, eles nos auxiliam a ver uma parte do *dataframe*.
#
# O método *head* nos retorna por padrão as 5 primeiras linhas, mas podemos alterar este valor também.

# %%
dados.head()
# Out:
#    Id                        job  ... discount_salary  total_salary
# 0   1     OFICIAL ADMINISTRATIVO  ...             0.0       1929.34
# 1   2                   SD 2C PM  ...             0.0       2265.96
# 2   3                   1TEN  PM  ...             0.0       6933.04
# 3   4                   MAJ   PM  ...             0.0      10568.36
# 4   5  AG.TEC. DE ASSIT. A SAUDE  ...             0.0       3561.88
#
# [5 rows x 10 columns]

# %% [markdown]
# Já o método *tail* por padrão nos retorna as 5 últimas linhas.

# %%
dados.tail()
# Out:
#               Id  ... total_salary
# 1084754  1085674  ...      1276.94
# 1084755  1085675  ...      1385.36
# 1084756  1085676  ...      1424.29
# 1084757  1085677  ...      2286.20
# 1084758  1085678  ...      9027.02
#
# [5 rows x 10 columns]

# %% [markdown]
# O método *info* retorna algumas informações úteis, como os tipos de dados por coluna e quantidade de linhas e colunas do *dataframe*.

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084759 entries, 0 to 1084758
# Data columns (total 10 columns):
# Id                 1084759 non-null int64
# job                1084731 non-null object
# sector             1084759 non-null object
# Month_salary       1084759 non-null float64
# 13_salary          1084759 non-null float64
# eventual_salary    1084759 non-null float64
# indemnity          1084759 non-null float64
# extra_salary       1084759 non-null float64
# discount_salary    1084759 non-null float64
# total_salary       1084759 non-null float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 82.8+ MB

# %% [markdown]
# Os itens únicos são retornados em ordem de aparecimento.

# %%
dados.sector.unique()
# Out:
# array(['DETRAN', 'PM', 'SPPREV', 'HCFMUSP', 'ADM GERAL', 'EDUCACAO',
#        'PGE', 'SAP', 'PRODESP', 'SSP', 'FUND. CASA', 'SAUDE', 'CDHU',
#        'CPTM', 'METRO', 'DAEE', 'DAESP', 'SABESP', 'DER', 'SAA', 'HCFMRP',
#        'CEETEPS', 'PROCON', 'FAZENDA', 'SECRETARIA', 'FURP', 'ITESP',
#        'MEIO AMBIE', 'SUCEN', 'FDE', 'UNIVESP', 'ZOOLOGICO', 'IPT',
#        'IMESP', 'SDS', 'INSTITUTO', 'CESP', 'TRANSP. ME', 'EMTU',
#        'PRO-SANGUE', 'SEPLAN', 'CPOS', 'IPEM', 'FAMEMA', 'PE. ANCHIE',
#        'CETESB', 'DERSA', 'TURISMO', 'FUND. FLOR', 'EMAE', 'HCFMB',
#        'CULTURA', 'FMSJRPRETO', 'EMPLASA', 'JUSTICA', 'CODASP', 'FUNAP',
#        'SDECTI', 'CIA DOCAS', 'SERT', 'ESPORTE', 'CASA CIVIL',
#        'RECURSOS H', 'FAPESP', 'ENERGIA', 'JUCESP', 'MEMORIAL', 'IPESP',
#        'FOSP', 'HABITACAO', 'SEADE', 'DESENVOLVE', 'IMESC', 'ARSESP',
#        'SPPREVCOM', 'AGEMVALE', 'SDPD', 'ARTESP', 'TRANSPORTE', 'CPSEC',
#        'CBPM', 'AGEMCAMP', 'COSESP', 'CPP', 'AGEM', 'GAB GOV',
#        'SP.CLIN.FA'], dtype=object)

# %% [markdown]
# O atributo *shape* retorna as dimensões do dataframe

# %%
dados.shape
# Out:
# (1084759, 10)

# %% [markdown]
# O atributo *columns* retorna uma lista com os nomes das colunas do dataframe.

# %%
dados.columns
# Out:
# Index(['Id', 'job', 'sector', 'Month_salary', '13_salary', 'eventual_salary',
#        'indemnity', 'extra_salary', 'discount_salary', 'total_salary'],
#       dtype='object')

# %% [markdown]
# ## <font color='Magenta'> Resposta - Desafio 2 </font>
#
#
# * Queremos visualizar apenas os 15 primeiros registros do dataframe.
#
# * Queremos visualizar apenas os 20 últimos registros do dataframe.

# %%
dados.head(15)
# Out:
#     Id                                      job  ... discount_salary  total_salary
# 0    1                   OFICIAL ADMINISTRATIVO  ...             0.0       1929.34
# 1    2                                 SD 2C PM  ...             0.0       2265.96
# 2    3                                 1TEN  PM  ...             0.0       6933.04
# 3    4                                 MAJ   PM  ...             0.0      10568.36
# 4    5                AG.TEC. DE ASSIT. A SAUDE  ...             0.0       3561.88
# 5    6                                 SD 1C PM  ...             0.0       4152.98
# 6    7                                 1CFO  PM  ...             0.0       1967.28
# 7    8  BENEFICIARIO DE SERVIDOR ESTADUAL-IPESP  ...             0.0       1699.19
# 8    9                                 CABO  PM  ...             0.0       2703.47
# 9   10                                 SD 1C PM  ...             0.0       3010.04
# 10  11             PROFESSOR EDUCACAO BASICA II  ...             0.0       3273.70
# 11  12                 COMPLEM. PENSAO - FEPASA  ...             0.0       1117.45
# 12  13   BENEFICIARIO DA POLICIA MILITAR - CBPM  ...             0.0      11023.01
# 13  14              PROFESSOR EDUCACAO BASICA I  ...             0.0       2449.03
# 14  15                                 1SGT  PM  ...             0.0       3400.74
#
# [15 rows x 10 columns]

# %%
dados.tail(20)
# Out:
#               Id  ... total_salary
# 1084739  1085659  ...      4512.04
# 1084740  1085660  ...      2341.02
# 1084741  1085661  ...      1012.09
# 1084742  1085662  ...      4378.20
# 1084743  1085663  ...      2497.16
# 1084744  1085664  ...      4807.72
# 1084745  1085665  ...      2370.06
# 1084746  1085666  ...      2937.58
# 1084747  1085667  ...       925.49
# 1084748  1085668  ...      2677.84
# 1084749  1085669  ...      5995.53
# 1084750  1085670  ...       259.24
# 1084751  1085671  ...      2093.99
# 1084752  1085672  ...      2736.65
# 1084753  1085673  ...      1338.84
# 1084754  1085674  ...      1276.94
# 1084755  1085675  ...      1385.36
# 1084756  1085676  ...      1424.29
# 1084757  1085677  ...      2286.20
# 1084758  1085678  ...      9027.02
#
# [20 rows x 10 columns]

# %% [markdown]
# ## <font color='Magenta'> Filtrando os dados do arquivo </font>
#
# Podemos escolher uma única coluna para visualizar.

# %%
dados['sector']
# Out:
# 0           DETRAN
# 1               PM
# 2               PM
# 3           SPPREV
# 4          HCFMUSP
#             ...
# 1084754     SPPREV
# 1084755     SPPREV
# 1084756     SPPREV
# 1084757     SPPREV
# 1084758     SPPREV
# Name: sector, Length: 1084759, dtype: object

# %% [markdown]
# Usando os operadores de comparação para filtrar uma informação específica.

# %%
dados['sector'] == 'EDUCACAO'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1084754    False
# 1084755    False
# 1084756    False
# 1084757    False
# 1084758    False
# Name: sector, Length: 1084759, dtype: bool

# %% [markdown]
# Filtrando os dados com operadores de comparacao

# %%
dados[dados['job'] == 'PROFESSOR EDUCACAO BASICA I']
# Out:
#               Id                          job  ... discount_salary  total_salary
# 13            14  PROFESSOR EDUCACAO BASICA I  ...             0.0       2449.03
# 19            20  PROFESSOR EDUCACAO BASICA I  ...             0.0       1942.26
# 20            21  PROFESSOR EDUCACAO BASICA I  ...             0.0       3462.18
# 23            24  PROFESSOR EDUCACAO BASICA I  ...             0.0       3116.40
# 29            30  PROFESSOR EDUCACAO BASICA I  ...             0.0       4106.75
# ...          ...                          ...  ...             ...           ...
# 1084729  1085649  PROFESSOR EDUCACAO BASICA I  ...             0.0       3647.43
# 1084736  1085656  PROFESSOR EDUCACAO BASICA I  ...             0.0       2862.27
# 1084743  1085663  PROFESSOR EDUCACAO BASICA I  ...             0.0       2497.16
# 1084745  1085665  PROFESSOR EDUCACAO BASICA I  ...             0.0       2370.06
# 1084748  1085668  PROFESSOR EDUCACAO BASICA I  ...             0.0       2677.84
#
# [128705 rows x 10 columns]

# %% [markdown]
# Filtrando com duas condições, usando operadores lógicos

# %%
dados[(dados['job'] == 'PROFESSOR EDUCACAO BASICA I') & (dados['discount_salary'] > 0)]
# Out:
# Empty DataFrame
# Columns: [Id, job, sector, Month_salary, 13_salary, eventual_salary, indemnity, extra_salary, discount_salary, total_salary]
# Index: []

# %% [markdown]
# Outro exemplo de filtro:

# %%
dados[(dados.sector == 'EDUCACAO') |
       (dados.sector == 'SAUDE') |
       (dados.sector == 'JUSTICA')].head()
# Out:
#     Id                            job  ... discount_salary  total_salary
# 16  17  AGENTE DE ORGANIZACAO ESCOLAR  ...             0.0       2106.49
# 29  30    PROFESSOR EDUCACAO BASICA I  ...             0.0       4106.75
# 48  49   PROFESSOR EDUCACAO BASICA II  ...             0.0       1316.32
# 62  63   PROFESSOR EDUCACAO BASICA II  ...             0.0       2897.89
# 64  65         OFICIAL ADMINISTRATIVO  ...             0.0       2386.21
#
# [5 rows x 10 columns]

# %% [markdown]
# Uma outra maneira de realizar o filtros acima, deixando ele mais limpo.

# %%
dados[dados.sector.isin(['EDUCACAO', 'SAUDE', 'JUSTICA'])].head()
# Out:
#     Id                            job  ... discount_salary  total_salary
# 16  17  AGENTE DE ORGANIZACAO ESCOLAR  ...             0.0       2106.49
# 29  30    PROFESSOR EDUCACAO BASICA I  ...             0.0       4106.75
# 48  49   PROFESSOR EDUCACAO BASICA II  ...             0.0       1316.32
# 62  63   PROFESSOR EDUCACAO BASICA II  ...             0.0       2897.89
# 64  65         OFICIAL ADMINISTRATIVO  ...             0.0       2386.21
#
# [5 rows x 10 columns]

# %% [markdown]
# Filtrar um *dataframe* pelas maiores categorias, no exemplo abaixo estamos filtrando pelos 5 maiores.

# %%
dados.sector.value_counts().head()
# Out:
# SPPREV      447539
# EDUCACAO    259238
# PM           83865
# SAUDE        49042
# SAP          44270
# Name: sector, dtype: int64

# %% [markdown]
# ## <font color='Magenta'> Resposta - Desafio 3 </font>

# %%
dados[(dados['sector'] == 'SAUDE') & (dados['job'] == 'OFICIAL ADMINISTRATIVO')]
# Out:
#               Id                     job  ... discount_salary  total_salary
# 64            65  OFICIAL ADMINISTRATIVO  ...             0.0       2386.21
# 498          499  OFICIAL ADMINISTRATIVO  ...             0.0       1367.53
# 619          620  OFICIAL ADMINISTRATIVO  ...             0.0       1974.05
# 641          642  OFICIAL ADMINISTRATIVO  ...             0.0       2369.58
# 1629        1632  OFICIAL ADMINISTRATIVO  ...             0.0       1571.89
# ...          ...                     ...  ...             ...           ...
# 1083668  1084588  OFICIAL ADMINISTRATIVO  ...             0.0       2492.59
# 1083691  1084611  OFICIAL ADMINISTRATIVO  ...             0.0       2016.50
# 1083963  1084883  OFICIAL ADMINISTRATIVO  ...             0.0       2325.91
# 1084061  1084981  OFICIAL ADMINISTRATIVO  ...             0.0        405.16
# 1084266  1085186  OFICIAL ADMINISTRATIVO  ...             0.0       3515.84
#
# [4175 rows x 10 columns]

# %% [markdown]
# ## <font color='Magenta'> Criando e excluindo colunas </font>
#
# Agora vamos criar uma nova coluna no nosso *dataframe*.

# %%
dados['total_salario'] = dados['Month_salary'] + dados['extra_salary']
dados.head(3)
# Out:
#    Id                     job  ... total_salary  total_salario
# 0   1  OFICIAL ADMINISTRATIVO  ...      1929.34        2389.66
# 1   2                SD 2C PM  ...      2265.96        3685.87
# 2   3                1TEN  PM  ...      6933.04        9617.73
#
# [3 rows x 11 columns]

# %% [markdown]
# Vamos exluir a coluna 'total_salario'.

# %%
dados.drop(columns='total_salario', axis = 1)
# Out:
#               Id  ... total_salary
# 0              1  ...      1929.34
# 1              2  ...      2265.96
# 2              3  ...      6933.04
# 3              4  ...     10568.36
# 4              5  ...      3561.88
# ...          ...  ...          ...
# 1084754  1085674  ...      1276.94
# 1084755  1085675  ...      1385.36
# 1084756  1085676  ...      1424.29
# 1084757  1085677  ...      2286.20
# 1084758  1085678  ...      9027.02
#
# [1084759 rows x 10 columns]

# %% [markdown]
# Vamos ver se realmente excluimos a coluna.

# %%
dados.head()
# Out:
#    Id                        job  ... total_salary  total_salario
# 0   1     OFICIAL ADMINISTRATIVO  ...      1929.34        2389.66
# 1   2                   SD 2C PM  ...      2265.96        3685.87
# 2   3                   1TEN  PM  ...      6933.04        9617.73
# 3   4                   MAJ   PM  ...     10568.36       13591.02
# 4   5  AG.TEC. DE ASSIT. A SAUDE  ...      3561.88        4203.67
#
# [5 rows x 11 columns]

# %% [markdown]
# Observamos que não foi excluida a coluna, por quê?
#
# Precisamos usar o argumento *inplace*.

# %%
dados.drop(columns='total_salario', axis = 1, inplace= True)

# %%
dados.head(3)
# Out:
#    Id                     job  ... discount_salary  total_salary
# 0   1  OFICIAL ADMINISTRATIVO  ...             0.0       1929.34
# 1   2                SD 2C PM  ...             0.0       2265.96
# 2   3                1TEN  PM  ...             0.0       6933.04
#
# [3 rows x 10 columns]

# %% [markdown]
# ## <font color='Magenta'> Resposta - Desafio 4 </font>
#
# Excluir a coluna ‘indemnity’ do dataframe, mas sem usar o atributo inplace.

# %%
dados.drop(columns='indemnity', axis = 1)
dados.head()
# Out:
#    Id                        job  ... discount_salary  total_salary
# 0   1     OFICIAL ADMINISTRATIVO  ...             0.0       1929.34
# 1   2                   SD 2C PM  ...             0.0       2265.96
# 2   3                   1TEN  PM  ...             0.0       6933.04
# 3   4                   MAJ   PM  ...             0.0      10568.36
# 4   5  AG.TEC. DE ASSIT. A SAUDE  ...             0.0       3561.88
#
# [5 rows x 10 columns]

# %% [markdown]
# ## <font color='Magenta'> Pivot Table </font>
#
# Podemos realizar uma tabela dinâmica usando a biblioteca **Pandas**.
#
# Usamos o método *sum* para somar as colunas numéricas.

# %%
dados.sum(numeric_only=True)
# Out:
# Id                 5.888714e+11
# Month_salary       4.719238e+09
# 13_salary          2.352580e+08
# eventual_salary    1.483163e+08
# indemnity          1.917648e+07
# extra_salary       1.260761e+08
# discount_salary   -1.032641e+08
# total_salary       3.682726e+09
# dtype: float64

# %% [markdown]
# Usamos o método *groupby* para agrupar os valores por alguma coluna, ex.: agrupando os valores por sector.

# %%
dados.groupby(by='sector', as_index=False).sum()
# Out:
#         sector           Id  ...  discount_salary  total_salary
# 0    ADM GERAL  17433579560  ...      -4806746.26   86480223.47
# 1         AGEM      9383056  ...             0.00      78311.37
# 2     AGEMCAMP      7808591  ...             0.00      71576.32
# 3     AGEMVALE      1092933  ...             0.00      26936.78
# 4       ARSESP     78147779  ...         -1317.12     826590.84
# ..         ...          ...  ...              ...           ...
# 82  TRANSP. ME    133659366  ...         -5510.00     649259.28
# 83  TRANSPORTE     43355933  ...             0.00     159218.20
# 84     TURISMO     30313730  ...         -9755.71     229830.02
# 85     UNIVESP    162358539  ...             0.00     655672.46
# 86   ZOOLOGICO    167178874  ...             0.00     671819.80
#
# [87 rows x 9 columns]

# %% [markdown]
# Usamos o método *groupby* para agrupar os valores com múltiplas colunas, ex.: agrupando valores por sector e job.

# %%
dados.groupby(by=['sector', 'job'], as_index=False).sum()
# Out:
#          sector  ... total_salary
# 0     ADM GERAL  ...   1442775.87
# 1     ADM GERAL  ...     46992.63
# 2     ADM GERAL  ...      5434.54
# 3     ADM GERAL  ...    533604.33
# 4     ADM GERAL  ...    221601.78
# ...         ...  ...          ...
# 5309  ZOOLOGICO  ...      3531.64
# 5310  ZOOLOGICO  ...      1487.10
# 5311  ZOOLOGICO  ...     57139.53
# 5312  ZOOLOGICO  ...      2363.18
# 5313  ZOOLOGICO  ...     38288.89
#
# [5314 rows x 10 columns]

# %% [markdown]
# Usando uma lista com nomes de colunas que queremos agrupar.
#
# Mas o que é uma lista? Uma lista (list) em Python é uma sequência ou coleção ordenada de valores.

# %%
lista = ['sector', 'job']
dados.groupby(by=lista, as_index=False).sum().head(3)
# Out:
#       sector  ... total_salary
# 0  ADM GERAL  ...   1442775.87
# 1  ADM GERAL  ...     46992.63
# 2  ADM GERAL  ...      5434.54
#
# [3 rows x 10 columns]

# %% [markdown]
# Usamos o *groupby* com a função *agg*, pois usando as duas conseguimos definir qual coluna vamos agrupar os dados e com coluna vamos usar para ter os valores, no exemplo abaixo, estamos usando a coluna *sector* para o agrupamento e a coluna *Month_salary* para ter os valores de média e quantidade.

# %%
dados.groupby('sector')['Month_salary'].agg(['mean', 'count'])
# Out:
#                    mean  count
# sector
# ADM GERAL   5043.169843  33156
# AGEM        4976.366111     18
# AGEMCAMP    6620.737143     14
# AGEMVALE    7685.922500      4
# ARSESP      8116.037899    138
# ...                 ...    ...
# TRANSP. ME  3042.367363    273
# TRANSPORTE  2487.528974     78
# TURISMO     4915.016833     60
# UNIVESP     2574.552871    310
# ZOOLOGICO   2529.287576    330
#
# [87 rows x 2 columns]

# %% [markdown]
# No Pandas temos uma função chamada *Pivot Table* que é exatamente o que fazemos no Excel.

# %%
pvt = dados[(dados.sector == 'EDUCACAO') |
       (dados.sector == 'SAUDE') |
       (dados.sector == 'JUSTICA')]

# %%
pvt.pivot_table(index = 'job', columns='sector', values='total_salary', aggfunc='count')
# Out:
# sector                         EDUCACAO  JUSTICA   SAUDE
# job
# AG.APOIO PESQ.CIENT.TECNOL.         NaN      NaN    61.0
# AG.TEC. DE ASSIT. A SAUDE          46.0      NaN  2817.0
# AGENTE DE ORGANIZACAO ESCOLAR   33516.0      NaN     NaN
# AGENTE DE SANEAMENTO                NaN      NaN   122.0
# AGENTE DE SAUDE                     NaN      NaN   331.0
# ...                                 ...      ...     ...
# SUPERVISOR TECNICO I                NaN      NaN     6.0
# TECN.APOIO PESQ.CIENT.TECNOL.       NaN      NaN   120.0
# TECNICO DE ENFERMAGEM               NaN      NaN  2483.0
# TECNICO DE LABORATORIO              NaN      NaN   846.0
# TECNICO DE RADIOLOGIA               NaN      NaN   627.0
#
# [128 rows x 3 columns]

# %% [markdown]
# A função *crosstab* realiza uma transposição dos dados.

# %%
pd.crosstab(pvt.sector,pvt.job)
# Out:
# job       AG.APOIO PESQ.CIENT.TECNOL.  ...  TECNICO DE RADIOLOGIA
# sector                                 ...
# EDUCACAO                            0  ...                      0
# JUSTICA                             0  ...                      0
# SAUDE                              61  ...                    627
#
# [3 rows x 128 columns]

# %% [markdown]
# ## <font color='Magenta'> Vlookup - Merge </font>
#
# O *vlookup* pode ser feito no pandas com o método *merge* e com o argumento *on*, o argumento *on* especifica a coluna que vamos usar para dar o *match* das colunas.

# %%
df1.merge(df2, on='id', how='left').head(3)
# Out:
#    id  age     sex    bmi  children smoker     region    charges  ID country
# 0   1   19  female  27.90         0    yes  southwest  168849.24   1  Brazil
# 1   2   18    male  33.77         1     no  southeast  172555.23   2  Brazil
# 2   3   28    male  33.00         3     no  southeast   44494.62   3  Brazil

# %% [markdown]
# ## <font color='Magenta'> Formatação </font>
#
# Nesta etapa, vamos aprender a formatar as colunas e os dados do nosso *dataframe*.
#
# O pandas possui um sistema de opções que permite personalizar alguns aspectos de seu comportamento, sendo as opções relacionadas à exibição dos dados que o usuário provavelmente ajustará.
#
# No exemplo abaixo vamos formatar as variáveis que contém valores, vamos deixar apenas um valor após a vírgula.

# %%
pd.set_option('display.float_format', '{:.1f}'.format)

# %%
df1.head(2)
# Out:
#    id  age     sex  bmi  children smoker     region  charges
# 0   1   19  female 27.9         0    yes  southwest 168849.2
# 1   2   18    male 33.8         1     no  southeast 172555.2

# %% [markdown]
# No exemplo abaixo vamos resetar a formatação que realizamos no exemplo acima.

# %%
pd.reset_option('display.float_format')

# %%
df1.head(2)
# Out:
#    id  age     sex    bmi  children smoker     region    charges
# 0   1   19  female  27.90         0    yes  southwest  168849.24
# 1   2   18    male  33.77         1     no  southeast  172555.23

# %% [markdown]
# Usando o atributo *str* + o método *title* conseguimos transformar o texto da variável para o padrão de começar com letra maiúscula.

# %%
df1['region'] = df1['region'].str.title()
df1.head(2)
# Out:
#    id  age     sex    bmi  children smoker     region    charges
# 0   1   19  female  27.90         0    yes  Southwest  168849.24
# 1   2   18    male  33.77         1     no  Southeast  172555.23

# %% [markdown]
# Usando o atributo *str* + o método *upper* conseguimos transformar o texto da variável para o padrão de deixar as letras mauísculas.

# %%
df1['region'] = df1['region'].str.upper()
df1.head(2)
# Out:
#    id  age     sex    bmi  children smoker     region    charges
# 0   1   19  female  27.90         0    yes  SOUTHWEST  168849.24
# 1   2   18    male  33.77         1     no  SOUTHEAST  172555.23

# %% [markdown]
# Usando o atributo *str* + o método *lower* conseguimos transformar o texto da variável para o padrão de deixar as letras minúsculas.

# %%
df1['region'] = df1['region'].str.lower()
df1.head(2)
# Out:
#    id  age     sex    bmi  children smoker     region    charges
# 0   1   19  female  27.90         0    yes  southwest  168849.24
# 1   2   18    male  33.77         1     no  southeast  172555.23

# %% [markdown]
# Usando o atributo *str* + o método *strip* remove os espaços em branco que tiver no texto.

# %%
df1['region'] = df1['region'].str.strip()
df1.head(2)
# Out:
#    id  age     sex    bmi  children smoker     region    charges
# 0   1   19  female  27.90         0    yes  southwest  168849.24
# 1   2   18    male  33.77         1     no  southeast  172555.23

# %% [markdown]
# Usando o método *rename* conseguimos mudar o nome das variáveis.

# %%
df1.rename(columns = {'region': 'região', 'age':'idade'}).head(3)
# Out:
#    id  idade     sex    bmi  children smoker     região    charges
# 0   1     19  female  27.90         0    yes  southwest  168849.24
# 1   2     18    male  33.77         1     no  southeast  172555.23
# 2   3     28    male  33.00         3     no  southeast   44494.62

# %% [markdown]
# Use a função *cut* quando precisar segmentar e classificar valores de dados em compartimentos.
#
# Essa função também é útil para passar de uma variável contínua para uma variável categórica. Por exemplo, pode converter idades em grupos de faixas etárias.

# %%
df1['categoria_idade'] = pd.cut(df1.age, bins=[0, 18, 50, 99], labels=['crianças', 'jovens', 'adultos'])
df1.head(3)
# Out:
#    id  age     sex    bmi  ...  smoker     region    charges  categoria_idade
# 0   1   19  female  27.90  ...     yes  southwest  168849.24           jovens
# 1   2   18    male  33.77  ...      no  southeast  172555.23         crianças
# 2   3   28    male  33.00  ...      no  southeast   44494.62           jovens
#
# [3 rows x 9 columns]

# %% [markdown]
# ## <font color='Magenta'> Formatação Condicional </font>
#
# Aqui vamos aprender a fazer formatação condicional no Python.
#
# Vamos formatar a variável 'bmi' para dois valores após a vírgula.

# %%
format_dict = {'bmi':'{:.2f}'}

# %% [markdown]
# Aqui vamos destacar a célula com o valor minímo e máximo da variável 'bmi'.

# %%
(df1.style.format(format_dict)
 .hide_index()
 .highlight_min('bmi', color='red')
 .highlight_max('bmi', color='lightgreen')
)
# Out:
# <style  type="text/css" >
#     #T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col3 {
#             : ;
#             background-color:  lightgreen;
#         }    #T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col3 {
#             background-color:  red;
#             : ;
#         }</style><table id="T_142fee46_58c5_11ea_b80b_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >age</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >bmi</th>        <th class="col_heading level0 col4" >children</th>        <th class="col_heading level0 col5" >smoker</th>        <th class="col_heading level0 col6" >region</th>        <th class="col_heading level0 col7" >charges</th>        <th class="col_heading level0 col8" >categoria_idade</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col1" class="data row0 col1" >19</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col2" class="data row0 col2" >female</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col3" class="data row0 col3" >27.90</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col5" class="data row0 col5" >yes</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col6" class="data row0 col6" >southwest</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col7" class="data row0 col7" >168849</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row0_col8" class="data row0 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col1" class="data row1 col1" >18</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col2" class="data row1 col2" >male</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col3" class="data row1 col3" >33.77</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col5" class="data row1 col5" >no</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col6" class="data row1 col6" >southeast</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col7" class="data row1 col7" >172555</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row1_col8" class="data row1 col8" >crianças</td>
#             </tr>
#             <tr>
#                                 <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col1" class="data row2 col1" >28</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col2" class="data row2 col2" >male</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col3" class="data row2 col3" >33.00</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col5" class="data row2 col5" >no</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col6" class="data row2 col6" >southeast</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col7" class="data row2 col7" >44494.6</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row2_col8" class="data row2 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col1" class="data row3 col1" >33</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col2" class="data row3 col2" >male</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col3" class="data row3 col3" >22705.00</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col5" class="data row3 col5" >no</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col6" class="data row3 col6" >northwest</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col7" class="data row3 col7" >2.19845e+07</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row3_col8" class="data row3 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col1" class="data row4 col1" >32</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col2" class="data row4 col2" >male</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col3" class="data row4 col3" >28.88</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col5" class="data row4 col5" >no</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col6" class="data row4 col6" >northwest</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col7" class="data row4 col7" >386686</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row4_col8" class="data row4 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col1" class="data row5 col1" >31</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col2" class="data row5 col2" >female</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col3" class="data row5 col3" >25.74</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col5" class="data row5 col5" >no</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col6" class="data row5 col6" >southeast</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col7" class="data row5 col7" >375662</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row5_col8" class="data row5 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row6_col1" class="data row6 col1" >46</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row6_col2" class="data row6 col2" >female</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row6_col3" class="data row6 col3" >33.44</td>
#                         <td id="T_142fee46_58c5_11ea_b80b_0242ac1c0002row6_col4" class="data row6 col4" >1</td>
#                         <td id="T_142fee46_58c5_1

# %% [markdown]
# Aqui vamos destacar a variável 'age' em degrade.

# %%
(df1.style.format(format_dict)
 .hide_index()
 .background_gradient(subset='age', cmap='Blues')
)
# Out:
# <style  type="text/css" >
#     #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col1 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col1 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col1 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col1 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row5_col1 {
#             background-color:  #b8d5ea;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row6_col1 {
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row7_col1 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row8_col1 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row9_col1 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row10_col1 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row11_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row12_col1 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row13_col1 {
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }    #T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row14_col1 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }</style><table id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002" ><thead>    <tr>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >age</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >bmi</th>        <th class="col_heading level0 col4" >children</th>        <th class="col_heading level0 col5" >smoker</th>        <th class="col_heading level0 col6" >region</th>        <th class="col_heading level0 col7" >charges</th>        <th class="col_heading level0 col8" >categoria_idade</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col1" class="data row0 col1" >19.00</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col2" class="data row0 col2" >female</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col3" class="data row0 col3" >27.9</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col5" class="data row0 col5" >yes</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col6" class="data row0 col6" >southwest</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col7" class="data row0 col7" >168849</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row0_col8" class="data row0 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col1" class="data row1 col1" >18.00</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col2" class="data row1 col2" >male</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col3" class="data row1 col3" >33.77</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col5" class="data row1 col5" >no</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col6" class="data row1 col6" >southeast</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col7" class="data row1 col7" >172555</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row1_col8" class="data row1 col8" >crianças</td>
#             </tr>
#             <tr>
#                                 <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col1" class="data row2 col1" >28.00</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col2" class="data row2 col2" >male</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col3" class="data row2 col3" >33</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col5" class="data row2 col5" >no</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col6" class="data row2 col6" >southeast</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col7" class="data row2 col7" >44494.6</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row2_col8" class="data row2 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col1" class="data row3 col1" >33.00</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col2" class="data row3 col2" >male</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col3" class="data row3 col3" >22705</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col5" class="data row3 col5" >no</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col6" class="data row3 col6" >northwest</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col7" class="data row3 col7" >2.19845e+07</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row3_col8" class="data row3 col8" >jovens</td>
#             </tr>
#             <tr>
#                                 <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col1" class="data row4 col1" >32.00</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col2" class="data row4 col2" >male</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col3" class="data row4 col3" >28.88</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col5" class="data row4 col5" >no</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col6" class="data row4 col6" >northwest</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col7" class="data row4 col7" >386686</td>
#                         <td id="T_eb6440c0_58c4_11ea_b80b_0242ac1c0002row4_col8" class="da

# %% [markdown]
# ## <font color='Magenta'> Gráfico </font>
#
# Para gerar gráficos em Python usamos as bibliotecas **seaborn** e **matplotlib**.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Seaborn é uma biblioteca de visualização de dados Python baseada no matplotlib. Ele fornece uma interface de alto nível para desenhar gráficos estatísticos atraentes e informativos.
#
# Vamos usar o *countplot* que é um tipo de gráfico, ele conta a quantidade de vezes que aparece uma determinada observação de texto.

# %%
sns.countplot(x='sex', data=df1)
plt.show()

# %% [markdown]
# Colocando título no gráfico.

# %%
sns.countplot(x='sex', data=df1)
plt.title('Quantidade por Genêro')
plt.show()

# %% [markdown]
# Colocando nome nos eixos X e Y do gráfico.

# %%
sns.countplot(x='sex', data=df1)
plt.title('Quantidade por Genêro')
plt.xlabel('Genêro')
plt.ylabel('Quantidade')
plt.show()
